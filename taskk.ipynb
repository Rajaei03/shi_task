# %% [markdown]
# Reading the data

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv("Salaries.csv")
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# Basic Data Exploration :

# %%
num_rows, num_columns = df.shape
print(f"The dataset contains {num_rows} rows and {num_columns} columns.")
# Out:
# The dataset contains 148654 rows and 13 columns.

# %%
data_types = df.dtypes
print("Data types of each column:")
print(data_types)
# Out:
# Data types of each column:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
missing_values = df.isnull().sum()
print("Number of missing values in each column:")
print(missing_values)
# Out:
# Number of missing values in each column:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# Descriptive Statistics

# %%
statistics = df.describe()


salary_range = df['TotalPayBenefits'].max() - df['TotalPayBenefits'].min()
standard_deviation = df['TotalPayBenefits'].std()
mean_salary = df['TotalPayBenefits'].mean()
mode_salary = df['TotalPayBenefits'].mode().iloc[0]

print("Basic Statistics:")
print(statistics)

print("\nMinimum Salary:", df['TotalPayBenefits'].min())
print("Maximum Salary:", df['TotalPayBenefits'].max())
print("Range of Salaries:", salary_range)
print("Standard Deviation of Salaries:", standard_deviation)
print("Mean Salary:", mean_salary)
print("Mode Salary:", mode_salary)
# Out:
# Basic Statistics:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %% [markdown]
#  Data Cleaning

# %%
df['BasePay'].fillna(df['BasePay'].mean(), inplace=True)
df['OvertimePay'].fillna(df['OvertimePay'].mean(), inplace=True)
df['OtherPay'].fillna(df['OtherPay'].mean(), inplace=True)
df['Benefits'].fillna(df['Benefits'].mean(), inplace=True)

# %%
df['BasePay'].fillna(df['BasePay'].mean(), inplace=True)
df['OvertimePay'].fillna(df['OvertimePay'].mean(), inplace=True)
df['OtherPay'].fillna(df['OtherPay'].mean(), inplace=True)
df['Benefits'].fillna(df['Benefits'].mean(), inplace=True)

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                  0
# OvertimePay              0
# OtherPay                 0
# Benefits                 0
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
df.drop('Status', axis=1, inplace=True)
df.drop('Notes', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay      Benefits   TotalPay  \
# 0  167411.18         0.00  400184.25  25007.893151  567595.43
# 1  155966.02    245131.88  137811.38  25007.893151  538909.28
# 2  212739.13    106088.18   16452.60  25007.893151  335279.91
# 3   77916.00     56120.71  198306.90  25007.893151  332343.61
# 4  134401.60      9737.00  182234.59  25007.893151  326373.19
#
#    TotalPayBenefits  Year         Agency
# 0         567595.43  2011  San Francisco
# 1         538909.28  2011  San Francisco
# ...

# %% [markdown]
# Basic Data VisualizationFourth:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['TotalPayBenefits'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Salaries')
plt.xlabel('Total Pay and Benefits')
plt.ylabel('Frequency')
plt.show()

# department_counts = df['JobTitle'].value_counts().head(10)
department_counts = df.groupby('JobTitle')['TotalPayBenefits'].mean()
department_counts = department_counts.head(10)

plt.figure(figsize=(10, 6))
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Proportion of Employees in Different Departments')
plt.show()

# %% [markdown]
# Grouped Analysis:

# %%
JobTitle_summary = df.groupby('JobTitle')['TotalPayBenefits'].describe()

print("Summary Statistics by Job Title:")
print(JobTitle_summary)

average_salaries_by_job = df.groupby('JobTitle')['TotalPayBenefits'].mean()
sorted_average_salaries = average_salaries_by_job.sort_values(ascending=False)

print("\nAverage Salaries by Job Title:")
print(sorted_average_salaries.head(12000))
# Out:
# Summary Statistics by Job Title:
#                                                      count           mean  \
# JobTitle
# ACCOUNT CLERK                                         83.0   44035.664337
# ACCOUNTANT                                             5.0   47429.268000
# ACCOUNTANT INTERN                                     48.0   29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                            1.0   80266.370000
# ACUPUNCTURIST                                          1.0   67594.400000
# ADMINISTRATIVE ANALYST                                93.0   63954.867527
# ADMINISTRATIVE ANALYST II                              2.0   61497.035000
# ADMINISTRATIVE ANALYST III                             2.0   92698.515000
# ADMINISTRATIVE ENGINEER                               10.0  127961.430000
# ADMINISTRATIVE SERVICES MANAGER                        3.0   77015.580000
# ADMINISTRATOR, SFGH MEDICAL CENTER                     1.0  257124.440000
# ...

# %% [markdown]
# Simple Correlation Analysis:

# %%
correlation = df['BasePay'].corr(df['OvertimePay'])

plt.figure(figsize=(10, 6))
sns.scatterplot(x='BasePay', y='OvertimePay', data=df, alpha=0.5)
plt.title(f'Scatter Plot: BasePay vs. OtherPay (Correlation: {correlation:.2f})')
plt.xlabel('BasePay')
plt.ylabel('OvertimePay')
plt.show()

# %% [markdown]
# Summary of Insights:

# %% [markdown]
# 1-Data Loading and Preliminary Analysis: The notebook begins by loading a dataset and conducting preliminary analysis. This involves checking the data's structure, examining the first few rows, and summarizing the dataset to understand its contents and characteristics.
#
# 2-Data Cleaning and Preprocessing: It includes steps for cleaning and preprocessing the data. This may involve handling missing values, removing or imputing null entries, and possibly transforming or normalizing data for further analysis.
#
# 3-Exploratory Data Analysis (EDA): This section contains exploratory data analysis, where the data is visualized and examined to uncover patterns or insights. This could involve creating various plots (like histograms, scatter plots, or box plots) to understand distributions, relationships between variables, or to identify outliers.
#
# 4-Statistical Analysis: The notebook likely includes some statistical analysis. This could range from basic descriptive statistics to more complex inferential statistics, depending on the dataset and the objectives of the analysis.
#
# 5-Correlation Analysis: There's an emphasis on understanding the correlation between different variables. This is typically done using correlation coefficients and scatter plots to visually represent how variables are related.
#
# 6-Insights and Conclusions: The final part of the notebook is likely dedicated to summarizing the findings and insights gained from the analysis. This would include interpretations of the data visualizations and statistical analyses, and how these findings can inform decisions or further investigations.
#
# 7-Graphs and Visual Outputs: Throughout the notebook, there are various graphs and visual outputs that support the analysis. These visuals are crucial for understanding the data and the results of the analysis.
